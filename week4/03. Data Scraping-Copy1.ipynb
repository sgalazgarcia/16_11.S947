# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # Data Scraping

# %% [markdown]
# ### 0. Importing the library
#
# First we need to import the libraries, and some of their components. We will be using **Twython**, a library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
# ```
# pip install twython
# ```
#
# We also need to create a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. If you haven’t done so, at this point you should obtain your twitter API keys. Create a python file on the same directory of your **IPython** notebook, and name it: **`twitter_key.py`**.
#
# ```
# # In the file you should define two variables:
# t_key = ‘your twitter key’
# t_secret = ‘your twitter secret’
# ```
#
# Get your Twitter key and secret code on the [Twitter Apps site](https://apps.twitter.com/). You will need to create an application, it doesn't matter what you call it, to get your key and secret code. Once your application is created, you will find your keys on the **Keys and Access Tokens** tab of your application.

# %%
import json
import time
import threading

from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key import t_key, t_secret

# %% [markdown]
# ### 1. Query the Twitter API
# Now we are going to construct a **Twython** object; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.
#
# Additional documentation of the Twython API can be found [here]( https://twython.readthedocs.org/en/latest/)

# %%
# Assigns the keys to the variables
APP_KEY = t_key
APP_SECRET = t_secret


# Setup a Lat Lon
# MIT Coordinates: 42.3598, 71.0921

# latlong = [24.6333, 46.7167]
latlong = [42.3598, -71.0921]

''' Fetches tweets with a given query at a given lat-long.'''
def get_tweets( latlong=None ):
    # Creates a Twithon object with the given keys
    twitter = Twython( APP_KEY, APP_SECRET )
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = twitter.search( geocode=','.join([ str(x) for x in latlong ]) + ',2km', result_type='recent', count=10000)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

print get_tweets(latlong)
# Out:
# [{u'contributors': None, u'truncated': False, u'text': u'Just posted a photo @ Island Creek Oyster Bar https://t.co/7eRaTgZW4x', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 705187466412560384, u'favorite_count': 0, u'source': u'<a href="http://instagram.com" rel="nofollow">Instagram</a>', u'retweeted': False, u'coordinates': {u'type': u'Point', u'coordinates': [-71.0955089, 42.34879096]}, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': [{u'url': u'https://t.co/7eRaTgZW4x', u'indices': [46, 69], u'expanded_url': u'https://www.instagram.com/p/BCeH_kHmUwW/', u'display_url': u'instagram.com/p/BCeH_kHmUwW/'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'705187466412560384', u'favorited': False, u'user': {u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 16174462, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/507183612060385280/pKV5Y8AN.jpeg', u'verified': False, u'profile_text_color': u'3C3940', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/696723221849120769/2NSRd3v5_normal.jpg', u'profile_sidebar_fill_color': u'95E8EC', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/BAAX0k64ur', u'indices': [0, 23], u'expanded_url': u'http://about.me/warren.bobrow', u'display_url': u'about.me/warren.bobrow'}]}, u'description': {u'urls': []}}, u'followers_count': 10573, u'profile_sidebar_border_color': u'000000', u'id_str': u'16174462', u'profile_background_color': u'0099B9', u'listed_count': 464, u'is_translation_enabled': False, u'utc_offset': -18000, u'statuses_count': 75904, u'description': u'4x Author, Mezan Rum brand ambassador, Moscow Bar Show, Spirited Award Nominee-Tales of the Cocktail,Saveur100, Distiller, DrinkupNY, Foodista, Eater, Chilled', u'friends_count': 10364, u'location': u'iPhone: 40.779125,-74.514015', u'profile_link_color': u'4A913C', u'profile_image_url': u'http://pbs.twimg.com/profile_images/696723221849120769/2NSRd3v5_normal.jpg', u'following': None, u'geo_enabled': True, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/16174462/1454946753', u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/507183612060385280/pKV5Y8AN.jpeg', u'screen_name': u'WarrenBobrow1', u'lang': u'en', u'profile_background_tile': True, u'favourites_count': 31060, u'name': u'Warren Bobrow', u'notifications': None, u'url': u'https://t.co/BAAX0k64ur', u'created_at': u'Sun Sep 07 22:12:52 +0000 2008', u'contributors_enabled': False, u'time_zone': u'Eastern Time (US & Canada)', u'protected': False, u'default_profile': False, u'is_translator': False}, u'geo': {u'type': u'Point', u'coordinates': [42.34879096, -71.0955089]}, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Thu Mar 03 00:26:08 +0000 2016', u'in_reply_to_status_id_str': None, u'place': {u'full_name': u'Boston, MA', u'url': u'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json', u'country': u'United States', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-71.191421, 42.227797], [-70.986004, 42.227797], [-70.986004, 42.399542], [-71.191421, 42.399542]]]}, u'contained_within': [], u'country_code': u'US', u'attributes': {}, u'id': u'67b98f17fdcf20be', u'name': u'Boston'}, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}, {u'contributors': None, u'truncated': False, u'text': u'This is round one: #eggplant, #tapanade, #lamb #tongue and #shirazi #salad #persianfood @ Lala Rokh https://t.co/YrV4bAtII7', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 705187441250926593, u'favorite_count': 0, u'source': u'<a href="http://instagram.com" rel="nofollow">Instagram</a>', u'retweeted': False, u'coordinates': {u'type': u'Point', u'coordinates': [-71.0697327, 42.3580704]}, ...

# %%
# ###################
# ASSIGNMENT CODE
# ##################

# Setup a Lat Lon
# MIT Coordinates: 42.3598, 71.0921

# latlong = [24.6333, 46.7167]
latlong = [42.3598, -71.0921]

''' Fetches tweets with a given query at a given lat-long.'''
def retrieve_tweets( latlong=None ):
    # Creates a Twithon object with the given keys
    twitter = Twython( APP_KEY, APP_SECRET )
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = twitter.search( geocode=','.join([ str(x) for x in latlong ]) + ',15km', result_type='recent', count=10000)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

print retrieve_tweets(latlong)
# Out:
# [{u'contributors': None, u'truncated': False, u'text': u'At the Garden. Go Celtics!', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 705187924485083136, u'favorite_count': 0, u'source': u'<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for i\u039fS</a>', u'retweeted': False, u'coordinates': {u'type': u'Point', u'coordinates': [-71.06191437, 42.36619288]}, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': []}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'705187924485083136', u'favorited': False, u'user': {u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 515725199, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme14/bg.gif', u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/587283303721480192/eZNK7sZf_normal.jpg', u'profile_sidebar_fill_color': u'EFEFEF', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/XFBTX9gTEj', u'indices': [0, 23], u'expanded_url': u'http://searchdatacenter.techtarget.com/ezine/Modern-Infrastructure', u'display_url': u'searchdatacenter.techtarget.com/ezine/Modern-I\u2026'}]}, u'description': {u'urls': []}}, u'followers_count': 726, u'profile_sidebar_border_color': u'EEEEEE', u'id_str': u'515725199', u'profile_background_color': u'131516', u'listed_count': 58, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 4804, u'description': u"Managing Editor for TechTarget's @ModernInfra, News Editor for Data Center and Virtualization media group.", u'friends_count': 1287, u'location': u'Woostah', u'profile_link_color': u'009999', u'profile_image_url': u'http://pbs.twimg.com/profile_images/587283303721480192/eZNK7sZf_normal.jpg', u'following': None, u'geo_enabled': True, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/515725199/1454603579', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme14/bg.gif', u'screen_name': u'AdamHughesTT', u'lang': u'en', u'profile_background_tile': True, u'favourites_count': 476, u'name': u'Adam Hughes', u'notifications': None, u'url': u'https://t.co/XFBTX9gTEj', u'created_at': u'Mon Mar 05 18:23:04 +0000 2012', u'contributors_enabled': False, u'time_zone': None, u'protected': False, u'default_profile': False, u'is_translator': False}, u'geo': {u'type': u'Point', u'coordinates': [42.36619288, -71.06191437]}, u'in_reply_to_user_id_str': None, u'lang': u'en', u'created_at': u'Thu Mar 03 00:27:57 +0000 2016', u'in_reply_to_status_id_str': None, u'place': {u'full_name': u'Boston, MA', u'url': u'https://api.twitter.com/1.1/geo/id/67b98f17fdcf20be.json', u'country': u'United States', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-71.191421, 42.227797], [-70.986004, 42.227797], [-70.986004, 42.399542], [-71.191421, 42.399542]]]}, u'contained_within': [], u'country_code': u'US', u'attributes': {}, u'id': u'67b98f17fdcf20be', u'name': u'Boston'}, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}, {u'contributors': None, u'truncated': False, u'text': u'Just posted a photo @ Boston, Massachusetts https://t.co/Wvokq45IYN', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 705187903370964997, u'favorite_count': 0, u'source': u'<a href="http://instagram.com" rel="nofollow">Instagram</a>', u'retweeted': False, u'coordinates': {u'type': u'Point', u'coordinates': [-71.0617, 42.3578]}, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [], u'urls': [{u'url': u'https://t.co/Wvokq45IYN', u'indices': [44, 67], u'expanded_url': u'https://www.instagram.com/p/BCeIMSWGUwq/', u'display_url': u'instagram.com/p/BCeIMSWGUwq/'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'705187903370964997', u'favorited ...

# %% [markdown]
# ### 2. Hit the API and Parse the Result
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure. It can be sometimes hard to read a raw JSON. I find it easy to use some online parses like [this]( http://json.parser.online.fr/) to look at the structure of the JSON, and only access what we care about.

# %%
""" Does pretty much what its long name suggests. """
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 120
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 30 
    while remaining_seconds > 0:
        added = 0
        # We hit the Twitter API
        new_tweets = get_tweets( latlong )
        # We parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets and tweet['coordinates'] != None:
                properties = {}
                properties['lat'] = tweet['coordinates']['coordinates'][0]
                properties['lon'] = tweet['coordinates']['coordinates'][1]
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['user_location'] = tweet['user']['location']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print "At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets ) )
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    # We return the final dictionary
    return all_tweets

# %%
#  #####################
#  PROBLEM SET 3
#  #####################


def tweet_series ( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    minutes = 15
    total_time = minutes * 60
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 20 
    while remaining_seconds > 0:
        added = 0
        # We hit the Twitter API
        new_tweets = get_tweets( latlong )
        # We parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets and tweet['coordinates'] != None:
                properties = {}
                properties['lat'] = tweet['coordinates']['coordinates'][0]
                properties['lon'] = tweet['coordinates']['coordinates'][1]
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['user_location'] = tweet['user']['location']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print "At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets ) )
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    # We return the final dictionary
    return all_tweets

# %% [markdown]
# ### 3. Run the Functions
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called `twitter`, where I a m saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like `threading`.

# %%
'''This function executes the rest of the functions over a given period of time'''
def run():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            # We define a centroid in Riyadh
            latlong = [24.6333, 46.7167]
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( '%stweets.json' %(timestr), 'w' ) as f:
                f.write( json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run()
# Out:
# At 0 seconds, added 75 new tweets, for a total of 75
# At 30 seconds, added 0 new tweets, for a total of 75
# At 60 seconds, added 0 new tweets, for a total of 75
# At 90 seconds, added 0 new tweets, for a total of 75

# %%
# ###################
# ASSIGNMENT CODE
# ##################

'''This function executes the rest of the functions over a given period of time'''
def run2():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            # We define a centroid in MIT
            latlong = [42.3598, -71.0921]
            t = tweet_series( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( '%stweets.json' %(timestr), 'w' ) as f:
                f.write( json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run2()
# Out:
# At 0 seconds, added 83 new tweets, for a total of 83
# At 20 seconds, added 1 new tweets, for a total of 84
# At 40 seconds, added 0 new tweets, for a total of 84
# At 60 seconds, added 0 new tweets, for a total of 84
# At 80 seconds, added 0 new tweets, for a total of 84
# At 100 seconds, added 0 new tweets, for a total of 84
# At 120 seconds, added 1 new tweets, for a total of 85
# At 140 seconds, added 0 new tweets, for a total of 85
# At 160 seconds, added 1 new tweets, for a total of 86
# At 180 seconds, added 0 new tweets, for a total of 86
# At 200 seconds, added 0 new tweets, for a total of 86
# At 220 seconds, added 0 new tweets, for a total of 86
# At 240 seconds, added 0 new tweets, for a total of 86
# At 260 seconds, added 0 new tweets, for a total of 86
# At 280 seconds, added 0 new tweets, for a total of 86
# At 300 seconds, added 0 new tweets, for a total of 86
# At 320 seconds, added 0 new tweets, for a total of 86
# At 340 seconds, added 0 new tweets, for a total of 86
# At 360 seconds, added 0 new tweets, for a total of 86
# At 380 seconds, added 0 new tweets, for a total of 86
# At 400 seconds, added 0 new tweets, for a total of 86
# At 420 seconds, added 0 new tweets, for a total of 86
# At 440 seconds, added 1 new tweets, for a total of 87
# At 460 seconds, added 0 new tweets, for a total of 87
# At 480 seconds, added 0 new tweets, for a total of 87
# At 500 seconds, added 0 new tweets, for a total of 87
# At 520 seconds, added 0 new tweets, for a total of 87
# At 540 seconds, added 1 new tweets, for a total of 88
# At 560 seconds, added 1 new tweets, for a total of 89
# At 580 seconds, added 0 new tweets, for a total of 89
# At 600 seconds, added 0 new tweets, for a total of 89
# At 620 seconds, added 0 new tweets, for a total of 89
# At 640 seconds, added 0 new tweets, for a total of 89
# At 660 seconds, added 0 new tweets, for a total of 89
# At 680 seconds, added 0 new tweets, for a total of 89
# At 700 seconds, added 0 new tweets, for a total of 89
# At 720 seconds, added 1 new tweets, for a total of 90
# At 740 seconds, added 0 new tweets, for a total of 90
# At 760 seconds, added 0 new tweets, for a total of 90
# At 780 seconds, added 0 new tweets, for a total of 90
# At 800 seconds, added 0 new tweets, for a total of 90
# At 820 seconds, added 1 new tweets, for a total of 91
# At 840 seconds, added 0 new tweets, for a total of 91
# At 860 seconds, added 2 new tweets, for a total of 93
# At 880 seconds, added 0 new tweets, for a total of 93

# %% [markdown]
# ### 4. Parse the JSONs
# Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.

# %%
# Import additional libraries
from os import listdir
from os.path import isfile, join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Get the file names from a given directory
file_dir = 'data/sample_tweets' # Set this to where your JSON saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# Initialize some lists to store the points, and the ids of the tweets
ids = []
all_pts = []
# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file)
    # Open the JSON
    with open(full_dir) as f:
        data = f.read()
        # Load the JSON as a dict
        dict = json.loads(data)
        # Only add the unique tweets to the list
        if not isinstance(dict, list):
            for key, val in dict.iteritems():
                if key not in ids:
                    ids.append(key)
                    lat = val['lat']
                    lon = val['lon']
                    all_pts.append([lat,lon])
pts = np.array(all_pts)
pts
# Out:
# array([[-71.10194   ,  42.36416   ],
#        [-71.093023  ,  42.342289  ],
#        [-71.0812306 ,  42.345885  ],
#        [-71.09831218,  42.34460181],
#        [-71.07738434,  42.35079206],
#        [-71.1017172 ,  42.36405958],
#        [-71.076     ,  42.35      ],
#        [-71.10201208,  42.36328636],
#        [-71.1013086 ,  42.363697  ],
#        [-71.10177957,  42.36409228],
#        [-71.10364715,  42.34928852],
#        [-71.07096434,  42.36733545],
#        [-71.0817425 ,  42.35116335],
#        [-71.0824613 ,  42.3635847 ],
#        [-71.0812306 ,  42.345885  ],
#        [-71.0832041 ,  42.3464868 ],
#        [-71.0697327 ,  42.3580704 ],
#        [-71.10177957,  42.36409228],
#        [-71.0955089 ,  42.34879096],
#        [-71.09385   ,  42.34851   ],
#        [-71.07780244,  42.3471832 ],
#        [-71.07685142,  42.35119545],
#        [-71.08416448,  42.37374754],
#        [-71.10364715,  42.34928852],
#        [-71.0955089 ,  42.34879096],
#        [-71.0704066 ,  42.35788443],
#        [-71.08253807,  42.34862566],
#        [-71.09173113,  42.36001887],
#        [-71.10401821,  42.34964806],
#        [-71.10355216,  42.36522203],
#        [-71.1032591 ,  42.3647559 ],
#        [-71.0971914 ,  42.34644218],
#        [-71.08492468,  42.3464423 ],
#        [-71.069942  ,  42.354112  ],
#        [-71.095053  ,  42.350134  ],
#        [-71.08253807,  42.34862566],
#        [-71.08416667,  42.3475    ],
#        [-71.0959504 ,  42.34720973],
#        [-71.07541   ,  42.361635  ],
#        [-71.08163   ,  42.34893   ],
#        [-71.07738434,  42.35079206],
#        [-71.1014227 ,  42.3638089 ],
#        [-71.1014227 ,  42.3638089 ],
#        [-71.1096202 ,  42.3504745 ],
#        [-71.08565   ,  42.34706   ],
#        [-71.09637042,  42.34885662],
#        [-71.08566284,  42.371765  ],
#        [-71.07025704,  42.35334743],
#        [-71.069942  ,  42.354112  ],
#        [-71.0955089 ,  42.34879096],
#        [-71.09625991,  42.3431418 ],
#        [-71.1017172 ,  42.36405958],
#        [-71.08722532,  42.34926983],
#        [-71.1017172 ,  42.36405958],
#        [-71.08594279,  42.36225098],
#        [-71.07496   ,  42.348594  ],
#        [-71.10093689,  42.34367371],
#        [-71.0955089 ,  42.34879096],
#        [-71.0955089 ,  42.34879096],
#        [-71.08717173,  42.34712664],
#        [-71.0707    ,  42.3519    ],
#        [-71.1013086 ,  42.363697  ],
#        [-71.1013086 ,  42.363697  ],
#        [-71.1013086 ,  42.363697  ],
#        [-71.07685142,  42.35119545],
#        [-71.08118168,  42.36141684],
#        [-71.08035556,  42.35129444],
#        [-71.0760069 ,  42.3686434 ],
#        [-71.1017172 ,  42.36405958],
#        [-71.0697327 ,  42.3580704 ],
#        [-71.07586251,  42.34957525],
#        [-71.08416667,  42.34916667],
#        [-71.10612275,  42.34996438],
#        [-71.08645441,  42.3456462 ],
#        [-71.07222153,  42.35063849],
#        [-71.0983    ,  42.373     ],
#        [-71.1039734 ,  42.3609581 ],
#        [-71.0824613 ,  42.3635847 ],
#        [-71.08416667,  42.34916667],
#        [-71.0955089 ,  42.34879096],
#        [-71.1017172 ,  42.36405958],
#        [-71.0884705 ,  42.3468094 ],
#        [-71.10265894,  42.34368603],
#        [-71.08761792,  42.34701103],
#        [-71.0955089 ,  42.34879096],
#        [-71.09164679,  42.36296552],
#        [-71.07600556,  42.35622778],
#        [-71.09844809,  42.34445967],
#        [-71.0971914 ,  42.34644218],
#        [-71.1017172 ,  42.36405958],
#        [-71.09048981,  42.37708334],
#        [-71.09173113,  42.36001887],
#        [-71.097415  ,  42.343463  ]])

# %%
# ###################
# ASSIGNMENT CODE
# ##################

## TWO ATTRIBUTES COVERED: ID, LATITUDE, LONGITUDE, CONTENT (I was unable to export the third one automatically to a cvf file)

# Import additional libraries
from os import listdir
from os.path import isfile, join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Get the file names from a given directory
file_dir = 'data/' # Set this to where your JSON saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# Initialize some lists to store the points, and the ids of the tweets
ids = []
all_pts = []
# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file)
    # Open the JSON
    with open(full_dir) as f:
        data = f.read()
        # Load the JSON as a dict
        dict = json.loads(data)
        # Only add the unique tweets to the list
        if not isinstance(dict, list):
            for key, val in dict.iteritems():
                if key not in ids:
                    ids.append(key)
                    lat = val['lat']
                    lon = val['lon']
                    latlon = val['lat'] * val['lon']
                    tid = val['tweet_id']
                    content = val['content']
                    all_pts.append([lat,lon, latlon, tid, content])
pts = np.array(all_pts)
# pts

np.savetxt("PSET90.csv", pts[:,[0]],fmt="%s", delimiter=",")
np.savetxt("PSET91.csv", pts[:,[1]],fmt="%s", delimiter=",")
np.savetxt("PSET92.csv", pts[:,[2]],fmt="%s", delimiter=",")
np.savetxt("PSET93.csv", pts[:,[3]],fmt="%s", delimiter=",")
# np.savetxt("PSET34.csv", pts[:,[4]],fmt="%s", delimiter=",")
# NOTE: I didn't do for the content of the twitter because the following error appeared:
# 'ascii' codec can't encode character u
# Instead, I cleaneed this column directly into excel. 


s = pts[:,[4]]
for i in s:
   i[0].encode("utf8")


# pts [:,[4]]

# %% [markdown]
# ### 5. Plot some Tweets
# We can use **matplotlib** to visualize some tweets.

# %%
# Add your code below:
x = np.linspace(0, 20, 100)
y = np.sin(x)

# latlong = pts [:,[2]]
# colors = plt.cm.coolwarm(pts[:,[2]])
# colors
# latlong
# colors
# zmean = lat ['mean']
# scaled_zmean = lat - scaled_zmean

# scaled_z = (z - z.min()) / z.ptp()
# colors = plt.cm.coolwarm(scaled_z)

# plt.scatter(x, y, marker='+', c=colors, s=100, linewidths=4)
# plt.show()

# Use a scatter plot to make a quick visualization of the data points
plt.scatter(pts[:,0], pts[:,1],c=pts[:,[2]])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Tweets around MIT')

# plt.show()

# %% [markdown]
# Lets make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe:
#
# * Construct a list with unique id's
# * Only add the tweets to the `numpy.array` if the tweet doesn't exist in the list.

# %%
# ###################
# ASSIGNMENT CODE
# ##################

# Add your code below:
x = np.linspace(0, 20, 100)
y = np.sin(x)

# latlong = pts [:,[2]]
# colors = plt.cm.coolwarm(pts[:,[2]])
# colors
# latlong
# colors
# zmean = lat ['mean']
# scaled_zmean = lat - scaled_zmean

# scaled_z = (z - z.min()) / z.ptp()
# colors = plt.cm.coolwarm(scaled_z)

# plt.scatter(x, y, marker='+', c=colors, s=100, linewidths=4)
# plt.show()

# Use a scatter plot to make a quick visualization of the data points
plt.scatter(pts[:,0], pts[:,1],c=pts[:,[2]])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Tweets around MIT')

# plt.show()

# %% [markdown]
# ### Problem Set - Extend What you Learned
#
# Now that you know how to scrape data let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrap data for 15 minutes and visualize. Think about what you would need to change to do that.
#
# Once you have the new json file of Boston tweets you should make a new array so that you can make a new scatter plot of your Boston tweets. When you make this new array you should get at least two different attributes returned by the Twitter api. One of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Plot the tweets with different colors (use lat/long to determine the colors) using the scatter plot tool. Then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Collect Tweets from Boston for 15 min. Note how you set the time in the above example, it was in seconds. How would you do that here?
#
# **2** - Plot your tweets using matplotlib.
#
# **3** - Change colors based on lat/long position.
#
# **4** - Save your array CSV file. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Iphython notebook of your scrapper, which includes your scattterplot.
#
# 2 - Your final CSV file.
#
# ### Bonus # 1
#
# Bonus  -- Do the orginally planned assignment now titled Bonus. If you do the whole thing you get a free homework assignment. If  you do parts of it you will get points to future assignments.
